# %% [markdown]
# ## **Projeto Python com Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Gapminder.csv', error_bad_lines=False, sep=';')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 3307     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
df.shape
# Out:
# (3312, 6)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 3307     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [3312 rows x 6 columns]>

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.count
# Out:
# <bound method DataFrame.count of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 3307     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [3312 rows x 6 columns]>

# %%
df.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.tail(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 3302  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 3303  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 3304  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 3305  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 3306  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 3307  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.describe()
# Out:
#               year      lifeExp           pop      gdpPercap
# count  3312.000000  3312.000000  3.312000e+03    3312.000000
# mean   1980.301630    65.246871  3.161489e+07   11317.115805
# std      16.927294    11.768412  1.041193e+08   11369.142739
# min    1950.000000    23.599000  5.941200e+04     241.165877
# 25%    1967.000000    58.337500  2.678572e+06    2514.625266
# 50%    1982.000000    69.610000  7.557218e+06    7838.505123
# 75%    1996.000000    73.657750  1.958522e+07   17357.879170
# max    2007.000000    82.670000  1.318683e+09  113523.132900

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
df_Oceania = df.loc[df['continent'] == 'Oceania']
df_Oceania
# Out:
#               country continent  year  lifeExp     pop    gdpPercap
# 975              Fiji   Oceania  1962   56.494  421869  2039.393277
# 976              Fiji   Oceania  1967   58.607  485000  2170.073285
# 977              Fiji   Oceania  1972   60.642  544000  2797.759484
# 978              Fiji   Oceania  1977   62.669  599339  3182.569600
# 979              Fiji   Oceania  1982   64.683  658906  3209.257468
# ...               ...       ...   ...      ...     ...          ...
# 2696  Solomon Islands   Oceania  1987   55.785  300694  1783.648762
# 2697  Solomon Islands   Oceania  1992   58.270  358713  2109.894257
# 2698  Solomon Islands   Oceania  1997   60.708  424265  2252.491044
# 2699  Solomon Islands   Oceania  2002   62.274  494786  1530.496068
# 2700  Solomon Islands   Oceania  2007   63.570  566842  1829.317402
#
# [74 rows x 6 columns]

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: country, dtype: int64

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283437
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
df.groupby('continent')['gdpPercap'].mean()
# Out:
# continent
# Africa       2138.088351
# Americas     8979.564475
# Asia        10070.908182
# Europe      16551.177664
# FSU          7903.069822
# Oceania     13078.961304
# Name: gdpPercap, dtype: float64

# %%
df['continent'].value_counts(ascending=False)
# Out:
# Europe      1302
# Africa       613
# Asia         557
# Americas     343
# FSU          122
# Oceania       74
# Name: continent, dtype: int64

# %%
df.groupby('continent')['gdpPercap'].mean().plot.bar();

# %%
df['continent'].value_counts(ascending=False).plot.bar();

# %%
import matplotlib.pyplot as plt
df.groupby('continent')['gdpPercap'].mean().plot.bar(title='PIB médio por Continente');

# %%
plt.style.use('ggplot')

# %%
df.groupby('continent')['gdpPercap'].mean().plot.bar(title='PIB médio por Continente');
plt.xlabel('Continente')
plt.ylabel('Valor do PIB U$')
plt.legend()

# %%
df.groupby('continent')['gdpPercap'].mean().plot.pie(title='PIB médio por Continente');

# %%
df.groupby('continent')['gdpPercap'].mean().plot.barh(title='PIB médio por Continente');
plt.ylabel('Continente')
plt.xlabel('Valor do PIB U$')
plt.legend()

# %%
plt.hist(df['gdpPercap'], color='blue');

# %% [markdown]
# # Utilizando o **AdventureWorks**

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_excel('/AdventureWorks.xlsx')
df
# Out:
#     Data Venda Data Envio  ID Loja  ...            Marca   Classe    Cor
# 0   2008-05-09 2008-05-29      199  ...  Adventure Works  Regular    Red
# 1   2008-05-12 2008-05-17      306  ...  Adventure Works  Regular    Red
# 2   2008-05-14 2008-05-20      306  ...  Adventure Works  Regular    Red
# 3   2008-05-21 2008-05-27      306  ...  Adventure Works  Regular    Red
# 4   2008-06-20 2008-06-27      306  ...  Adventure Works  Regular    Red
# ..         ...        ...      ...  ...              ...      ...    ...
# 899 2008-03-22 2008-04-04      306  ...         Fabrikam  Regular  Black
# 900 2008-10-04 2008-10-15      306  ...         Fabrikam  Regular  Black
# 901 2008-12-11 2008-12-15      306  ...         Fabrikam  Regular  Black
# 902 2008-12-17 2008-12-21      306  ...         Fabrikam  Regular  Black
# 903 2008-12-21 2008-12-25      306  ...         Fabrikam  Regular  Black
#
# [904 rows x 16 columns]

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
df.shape
# Out:
# (904, 16)

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
df['Custo'] = df['Custo Unitário'].mul(df['Quantidade'])

# %%
df.head(2)
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor    Custo
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red  2091.48
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red  2091.48
#
# [2 rows x 17 columns]

# %%
df['Custo'].sum()
# Out:
# 2486783.05

# %%
round(df['Custo'].sum(), 2)
# Out:
# 2486783.05

# %%
df['Lucro'] = df['Valor Venda'] - df['Custo']

# %%
df.head(2)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...   Classe  Cor    Custo    Lucro
# 0 2008-05-09 2008-05-29      199         384  ...  Regular  Red  2091.48  2456.52
# 1 2008-05-12 2008-05-17      306         384  ...  Regular  Red  2091.48  2456.52
#
# [2 rows x 18 columns]

# %%
df['Tempo Envio'] = df['Data Envio'] - df['Data Venda']

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor Tempo Envio
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red     20 days
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red      5 days
# 2 2008-05-14 2008-05-20      306  ...  Regular  Red      6 days
# 3 2008-05-21 2008-05-27      306  ...  Regular  Red      6 days
# 4 2008-06-20 2008-06-27      306  ...  Regular  Red      7 days
#
# [5 rows x 17 columns]

# %%
df['Tempo Envio'] = (df['Data Envio'] - df['Data Venda']).dt.days

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor Tempo Envio
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red          20
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red           5
# 2 2008-05-14 2008-05-20      306  ...  Regular  Red           6
# 3 2008-05-21 2008-05-27      306  ...  Regular  Red           6
# 4 2008-06-20 2008-06-27      306  ...  Regular  Red           7
#
# [5 rows x 17 columns]

# %%
df['Tempo Envio'].dtype
# Out:
# dtype('int64')

# %%
df.groupby('Marca')['Tempo Envio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo Envio, dtype: float64

# %%
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Tempo Envio       0
# dtype: int64

# %%
df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works    3.066412e+05
#             Contoso            5.641600e+04
#             Fabrikam           1.557021e+06
# 2009        Adventure Works    4.053951e+05
#             Contoso            1.382590e+05
#             Fabrikam           1.034091e+06
# Name: Lucro, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
Lucro_ano = df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum().reset_index()
Lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=True).plot.barh(title='Total Produtos Vendidos')
plt.xlabel('Total')
plt.ylabel('Produto');

# %%
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum().plot.bar(title='Lucro x Ano')
plt.xlabel('Ano')
plt.ylabel('Receita');

# %%
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: Lucro, dtype: float64

# %%
df_2009 = df[df['Data Venda'].dt.year == 2009]

# %%
df_2009.head()
# Out:
#    Data Venda Data Envio  ...                Custo                Lucro
# 11 2009-05-02 2009-05-14  ...             2,091.48             2,456.52
# 12 2009-05-16 2009-05-27  ...             2,091.48             2,456.52
# 13 2009-05-31 2009-06-12  ...             2,091.48             2,456.52
# 14 2009-06-28 2009-07-11  ...             2,091.48             2,456.52
# 15 2009-07-08 2009-07-12  ...             2,091.48             2,456.52
#
# [5 rows x 19 columns]

# %%
df_2009.groupby(df_2009['Data Venda'].dt.month)['Lucro'].sum().plot(title='Lucro x Mês')
plt.xlabel('Mês')
plt.ylabel('Receita');

# %%
df_2009.groupby('Marca')['Lucro'].sum().plot.bar(title='Lucro x Marca')
plt.xlabel('Marca')
plt.ylabel('Receita')
plt.xticks(rotation='horizontal');

# %%
df_2009.groupby('Classe')['Lucro'].sum().plot.bar(title='Lucro x Classe')
plt.xlabel('Classe')
plt.ylabel('Receita')
plt.xticks(rotation='horizontal');

# %%
df['Tempo Envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo Envio, dtype: float64

# %%
plt.boxplot(df['Tempo Envio']);

# %%
plt.hist(df['Tempo Envio']);

# %%
df['Tempo Envio'].min()
# Out:
# 4

# %%
df['Tempo Envio'].max()
# Out:
# 20

# %%
df[df['Tempo Envio'] == 20]
# Out:
#   Data Venda Data Envio  ...                Custo                Lucro
# 0 2008-05-09 2008-05-29  ...             2,091.48             2,456.52
#
# [1 rows x 19 columns]

# %%
df.to_csv('df_vendas_novo.csv', index=False)
